# %%
import pandas as pd

# %%
df = pd.read_csv('data/before_translate.csv')

# %%
# remove zhang jiayi column
# df = df.drop(columns=['group'])

# %%
df
# Out:
#                                                 uniq_id    id_new  \
# 0     https://www.douban.com/doubanapp/dispatch?uri=...  27172911
# 1     https://www.douban.com/doubanapp/dispatch?uri=...  27172911
# 2     https://www.douban.com/doubanapp/dispatch?uri=...  27172911
# 3     https://www.douban.com/doubanapp/dispatch?uri=...  27172911
# 4     https://www.douban.com/doubanapp/dispatch?uri=...  27172911
# ...                                                 ...       ...
# 8656  https://www.douban.com/doubanapp/dispatch?uri=...  35539600
# 8657  https://www.douban.com/doubanapp/dispatch?uri=...  35539600
# 8658  https://www.douban.com/doubanapp/dispatch?uri=...  33454980
# 8659  https://www.douban.com/doubanapp/dispatch?uri=...  33454980
# 8660  https://www.douban.com/doubanapp/dispatch?uri=...  33454980
#
#                   name  season    Premiere  Episode  episode_duration_new  \
# 0                 幕后之王     NaN  2019-01-05     46.0                  45.0
# ...

# %%
# where name  = 亲爱的，热爱的 change to Go Go Squid!
df.loc[df['name'] == '亲爱的，热爱的', 'name'] = 'Go Go Squid!'
df.loc[df['name'] == '陈情令', 'name'] = 'The Untamed'
df.loc[df['name'] == '你微笑时很美', 'name'] = 'Falling Into Your Smile'
df.loc[df['name'] == '香蜜沉沉烬如霜', 'name'] = 'Ashes of Love'
df.loc[df['name'] == '三生三世十里桃花', 'name'] = 'Eternal Love'
df.loc[df['name'] == '斗破苍穹', 'name'] = 'Battle Through the Heavens'
df.loc[df['name'] == '鹤唳华亭', 'name'] = 'The Listener'
df.loc[df['name'] == '庆余年 第一季', 'name'] = 'Joy of Life Season 1'
df.loc[df['name'] == '开端', 'name'] = 'Reset'
df.loc[df['name'] == '斗罗大陆', 'name'] = 'Douluo Continent'
df.loc[df['name'] == '女心理师', 'name'] = 'Psychologist'
df.loc[df['name'] =='与君初相识·恰似故人归', 'name'] = 'The Blue Whisper'
df.loc[df['name'] == '星汉灿烂·月升沧海', 'name'] = 'Love Like the Galaxy'
df.loc[df['name'] == '你是我的荣耀', 'name'] = 'You Are My Glory'
df.loc[df['name'] == '你是我的城池营垒', 'name'] = 'You Are My Hero'
df.loc[df['name'] == '沉香如屑·沉香重华', 'name'] = 'Immortal Samsara'
df.loc[df['name'] == '漫长的季节', 'name'] = 'The Long Season'
df.loc[df['name'] == '觉醒年代', 'name'] = 'Awakening Age'
df.loc[df['name'] == '去有风的地方', 'name'] = 'Meet Yourself'
df.loc[df['name'] == '热血同行', 'name'] = 'The Blood of Youth'
df.loc[df['name'] == '在一起', 'name'] = 'With You'
df.loc[df['name'] == '我才不要和你做朋友呢', 'name'] = 'I Don\'t Want To Be Friends With You'
df.loc[df['name'] == '我在他乡挺好的', 'name'] = 'Remembrance of Things Past'
df.loc[df['name'] == '爱很美味', 'name'] = 'Delicious Romance'
df.loc[df['name'] == '隐秘而伟大', 'name'] = 'Fearless Whispers'
df.loc[df['name'] == '隐秘的角落', 'name'] = 'The Bad Kids'
df.loc[df['name'] == '大江大河2', 'name'] = 'Big River2'
df.loc[df['name'] == '山海情', 'name'] = 'Minning Town'
df.loc[df['name'] == '沉默的真相', 'name'] = 'The Long Night'
df.loc[df['name'] == '三体', 'name'] = 'Three-Body'
df.loc[df['name'] == '长月烬明', 'name'] = 'Till The End Of The Moon'
df.loc[df['name'] == '余生，请多指教', 'name'] = 'The Oath of Love'
df.loc[df['name'] == '狼殿下', 'name'] = 'The Wolf'
df.loc[df['name'] == '以家人之名', 'name'] = 'Go Ahead'
df.loc[df['name'] == '三生三世枕上书', 'name'] = 'Three Lives, Three Worlds, The Pillow Book'
df.loc[df['name'] == '司藤', 'name'] = 'Rattan'
df.loc[df['name'] == '苍兰诀', 'name'] = 'Love Between Fairy and Devil'
df.loc[df['name'] == '长安十二时辰', 'name'] = 'The Longest Day In Chang\'an'
df.loc[df['name'] == '燕云台', 'name'] = 'The Legend of Xiao Chuo'
df.loc[df['name'] == '热血少年', 'name'] = 'Hot Blooded Youth'
df.loc[df['name'] == '热血同行', 'name'] = 'Forward Forever'
df.loc[df['name'] == '大山的女儿', 'name'] = 'Daughter of the Mountains'
df.loc[df['name'] == '山河令', 'name'] = 'Word of Honor'
df.loc[df['name'] == '青春有你 第二季', 'name'] = 'Youth With You Season 2'
df.loc[df['name'] == '狂飙', 'name'] = 'The Knockout'
df.loc[df['name'] == '功勋', 'name'] = 'Medal of the Republic'
df.loc[df['name'] == '乔家的儿女', 'name'] = 'The Bond'
df.loc[df['name'] == '一生一世', 'name'] = 'Forever and Ever'
df.loc[df['name'] == '世界欠我一个初恋', 'name'] = 'Lucky\'s First Love'
df.loc[df['name'] == '九流霸主', 'name'] = 'Overlord'
df.loc[df['name'] == '半是蜜糖半是伤', 'name'] = 'Love is Sweet'
df.loc[df['name'] == '周生如故', 'name'] = 'One and Only'
df.loc[df['name'] == '招摇', 'name'] = 'The Legends'
df.loc[df['name'] == '烈火军校', 'name'] = 'Arsenal Military Academy'
df.loc[df['name'] == '玉楼春', 'name'] = 'Song of Youth'
df.loc[df['name'] == '警察荣誉', 'name'] = 'Ordinary Greatness'
df.loc[df['name'] == '有翡', 'name'] = 'Legend of Fei'
df.loc[df['name'] == '长歌行', 'name'] = 'The Long Ballad'
df.loc[df['name'] == '点燃我，温暖你', 'name'] = 'Lighter and Princess'
df.loc[df['name'] == '传闻中的陈芊芊', 'name'] = 'The Romance of Tiger and Rose'
df.loc[df['name'] == '一闪一闪亮星星', 'name'] = 'Shining for One Thing'
df.loc[df['name'] == '百岁之好，一言为定', 'name'] = 'Forever Love'
df.loc[df['name'] == '且试天下', 'name'] = 'Who Rules the World'
df.loc[df['name'] == '幸福到万家', 'name'] = 'The Story Of Xing Fu'
df.loc[df['name'] == '重生之门', 'name'] = 'Be Reborn'
df.loc[df['name'] == '风起洛阳', 'name'] = 'Luoyang'
df.loc[df['name'] == '锦衣之下', 'name'] = 'Under the Power'
df.loc[df['name'] == '谁是凶手', 'name'] = 'Who is the Murderer'
df.loc[df['name'] == '破冰行动', 'name'] = 'The Thunder'
df.loc[df['name'] == '御赐小仵作', 'name'] = 'The Imperial Coroner'
df.loc[df['name'] == '下一站是幸福', 'name'] = 'Find Yourself'
df.loc[df['name'] == '特战荣耀', 'name'] = 'Glory of the Special Forces'
df.loc[df['name'] == '全职高手', 'name'] = 'The King\'s Avatar'
df.loc[df['name'] == '勇敢的翅膀', 'name'] = 'Yonggan de Chibang'
df.loc[df['name'] == '东八区的先生们', 'name'] = 'Gentlemen of East 8th'
df.loc[df['name'] == '梦华录', 'name'] = 'A Dream of Splendor'
df.loc[df['name'] == '明星大侦探互动衍生2之目标人物', 'name'] = 'Target Person'
df.loc[df['name'] == '长风渡', 'name'] = 'Destined'
df.loc[df['name'] == '卿卿日常', 'name'] = 'New Life Begins'
df.loc[df['name'] == '平凡的荣耀', 'name'] = 'The Ordinary Glory'
df.loc[df['name'] == '八零九零', 'name'] = 'Octogenarians and the 90s'
df.loc[df['name'] == '我们的新时代', 'name'] = 'Our New Era'
df.loc[df['name'] == '荣耀乒乓', 'name'] = 'Ping Pong'
df.loc[df['name'] == '与晨同光', 'name'] = 'Irreplaceable Love'
df.loc[df['name'] == '偷偷藏不住', 'name'] = 'Hidden Love'
df.loc[df['name'] == '我，喜欢你', 'name'] = 'Dating in the Kitchen'
df.loc[df['name'] == '三千鸦杀', 'name'] = 'Love of Thousand Years'
df.loc[df['name'] == '一不小心捡到爱', 'name'] = 'Please Feel at Ease Mr. Ling'
df.loc[df['name'] == '胡同', 'name'] = 'Hu Tong'
df.loc[df['name'] == '最动听的事', 'name'] = 'I Hear You'
df.loc[df['name'] == '国子监来了个女弟子', 'name'] = 'A Female Student Arrives at the Imperial College'
df.loc[df['name'] == '后浪', 'name'] = 'Gen Z'
df.loc[df['name'] == '青囊传', 'name'] = 'Prodigy Healer'
df.loc[df['name'] == '天雷一部之春花秋月', 'name'] = 'Love Better Than Immortality'


df.loc[df['actor_name'] == '王一博', 'actor_name'] = 'Wang Yibo'
df.loc[df['actor_name'] == '肖战', 'actor_name'] = 'Xiao Zhan'
df.loc[df['actor_name'] == '李现', 'actor_name'] = 'Li Xian'
df.loc[df['actor_name'] == '杨紫', 'actor_name'] = 'Yang Zi'
df.loc[df['actor_name'] == '杨幂', 'actor_name'] = 'Yang Mi'
df.loc[df['actor_name'] == '李一桐', 'actor_name'] = 'Li Yitong'
df.loc[df['actor_name'] == '王鹤棣', 'actor_name'] = 'Dylan Wang'
df.loc[df['actor_name'] == '肖宇晨', 'actor_name'] = 'Xiao Yuchen'
df.loc[df['actor_name'] == '程潇', 'actor_name'] = 'Cheng Xiao'
df.loc[df['actor_name'] == '张若昀', 'actor_name'] = 'Zhang Ruoyun'
df.loc[df['actor_name'] == '李沁', 'actor_name'] = 'Li Qin'
df.loc[df['actor_name'] == '李易峰', 'actor_name'] = 'Li Yifeng'
df.loc[df['actor_name'] == '赵丽颖', 'actor_name'] = 'Zhao Liying'
df.loc[df['actor_name'] == '李兰迪', 'actor_name'] = 'Li Landi'
df.loc[df['actor_name'] == '张彬彬', 'actor_name'] = 'Zhang Binbin'
df.loc[df['actor_name'] == '张翰', 'actor_name'] = 'Zhang Han'
df.loc[df['actor_name'] == '张雪迎', 'actor_name'] = 'Zhang Xueying'
df.loc[df['actor_name'] == '赵露思', 'actor_name'] = 'Zhao Lusi'
df.loc[df['actor_name'] == '吴磊', 'actor_name'] = 'Wu Lei'
df.loc[df['actor_name'] == '吴宣仪', 'actor_name'] = 'Wu Xuanyi'
df.loc[df['actor_name'] == '虞书欣', 'actor_name'] = 'Yu Shuxin'
df.loc[df['actor_name'] == '徐海乔', 'actor_name'] = 'Xu Haiqiao'
df.loc[df['actor_name'] == '翟潇闻', 'actor_name'] = 'Zhai Xiaowen'
df.loc[df['actor_name'] == '王一菲', 'actor_name'] = 'Wang Yifei'
df.loc[df['actor_name'] == '王大陆', 'actor_name'] = 'Wang Dalu'
df.loc[df['actor_name'] == '王俊凯', 'actor_name'] = 'Wang Junkai'
df.loc[df['actor_name'] == '王源', 'actor_name'] = 'Wang Yuan'
df.loc[df['actor_name'] == '王嘉尔', 'actor_name'] = 'Wang Jiaer'
df.loc[df['actor_name'] == '易烊千玺', 'actor_name'] = 'Yi Yangqianxi'
df.loc[df['actor_name'] == '王凯', 'actor_name'] = 'Wang Kai'
df.loc[df['actor_name'] == '赵今麦', 'actor_name'] = 'Zhao Jinmai'
df.loc[df['actor_name'] == '许凯', 'actor_name'] = 'Xu Kai'
df.loc[df['actor_name'] == '孟子义', 'actor_name'] = 'Meng Ziyi'
df.loc[df['actor_name'] == '张哲瀚', 'actor_name'] = 'Zhang Zhehan'
df.loc[df['actor_name'] == '张云龙', 'actor_name'] = 'Zhang Yunlong'
df.loc[df['actor_name'] == '张新成', 'actor_name'] = 'Zhang Xincheng'
df.loc[df['actor_name'] == '张铭恩', 'actor_name'] = 'Zhang Mingen'
df.loc[df['actor_name'] == '张若昀', 'actor_name'] = 'Zhang Ruoyun'
df.loc[df['actor_name'] == '张天爱', 'actor_name'] = 'Zhang Tianai'
df.loc[df['actor_name'] == '张翰', 'actor_name'] = 'Zhang Han'
df.loc[df['actor_name'] == '刘亦菲', 'actor_name'] = 'Liu Yifei'
df.loc[df['actor_name'] == '刘昊然', 'actor_name'] = 'Liu Haoran'
df.loc[df['actor_name'] == '刘诗诗', 'actor_name'] = 'Liu Shishi'
df.loc[df['actor_name'] == '刘涛', 'actor_name'] = 'Liu Tao'
df.loc[df['actor_name'] == '刘奕君', 'actor_name'] = 'Liu Yijun'
df.loc[df['actor_name'] == '刘以豪', 'actor_name'] = 'Liu Yihao'
df.loc[df['actor_name'] == '刘人语', 'actor_name'] = 'Liu Renyu'
df.loc[df['actor_name'] == '刘宇宁', 'actor_name'] = 'Liu Yuning'
df.loc[df['actor_name'] == '杨颖', 'actor_name'] = 'Angelababy'
df.loc[df['actor_name'] == '杨洋', 'actor_name'] = 'Yang Yang'
df.loc[df['actor_name'] == '杨采钰', 'actor_name'] = 'Yang Caiyu'
df.loc[df['actor_name'] == '杨超越', 'actor_name'] = 'Yang Chaoyue'
df.loc[df['actor_name'] == '迪丽热巴', 'actor_name'] = 'Dilraba Dilmurat'
df.loc[df['actor_name'] == '白敬亭', 'actor_name'] = 'Bai Jingting'
df.loc[df['actor_name'] == '白宇', 'actor_name'] = 'Bai Yu'
df.loc[df['actor_name'] == '白鹿', 'actor_name'] = 'Bai Lu'
df.loc[df['actor_name'] == '沈月', 'actor_name'] = 'Shen Yue'
df.loc[df['actor_name'] == '沈腾', 'actor_name'] = 'Shen Teng'
df.loc[df['actor_name'] == '胡一天', 'actor_name'] = 'Hu Yitian'
df.loc[df['actor_name'] == '胡歌', 'actor_name'] = 'Hu Ge'
df.loc[df['actor_name'] == '井柏然', 'actor_name'] = 'Jing Boran'
df.loc[df['actor_name'] == '黄子韬', 'actor_name'] = 'Huang Zitao'
df.loc[df['actor_name'] == '黄景瑜', 'actor_name'] = 'Huang Jingyu'
df.loc[df['actor_name'] == '黄明昊', 'actor_name'] = 'Huang Minghao'
df.loc[df['actor_name'] == '黄轩', 'actor_name'] = 'Huang Xuan'
df.loc[df['actor_name'] == '鹿晗', 'actor_name'] = 'Lu Han'
df.loc[df['actor_name'] == '王乾越', 'actor_name'] = 'Wang Qianyue'
df.loc[df['actor_name'] == '王楚然', 'actor_name'] = 'Wang Churan'
df.loc[df['actor_name'] == '王子文', 'actor_name'] = 'Wang Ziwen'
df.loc[df['actor_name'] == '王鹤润', 'actor_name'] = 'Wang Herun'
df.loc[df['actor_name'] == '王鸥', 'actor_name'] = 'Wang Ou'
df.loc[df['actor_name'] == '王骁', 'actor_name'] = 'Wang Xiao'
df.loc[df['actor_name'] == '任嘉伦', 'actor_name'] = 'Ren Jialun'
df.loc[df['actor_name'] == '谭松韵', 'actor_name'] = 'Tan Songyun'
df.loc[df['actor_name'] == '肖顺尧', 'actor_name'] = 'Xiao Shunyao'
df.loc[df['actor_name'] == '辰亦儒', 'actor_name'] = 'Calvin Chen'
df.loc[df['actor_name'] == '陈道明', 'actor_name'] = 'Chen Daoming'
df.loc[df['actor_name'] == '郭涛', 'actor_name'] = 'Guo Tao'
df.loc[df['actor_name'] == '郭京飞', 'actor_name'] = 'Guo Jingfei'
df.loc[df['actor_name'] == '马思纯', 'actor_name'] = 'Ma Sichun'
df.loc[df['actor_name'] == '马天宇', 'actor_name'] = 'Ma Tianyu'
df.loc[df['actor_name'] == '马可', 'actor_name'] = 'Mark Chao'
df.loc[df['actor_name'] == '马伊琍', 'actor_name'] = 'Ma Yili'
df.loc[df['actor_name'] == '成毅', 'actor_name'] = 'Cheng Yi'
df.loc[df['actor_name'] == '张睿', 'actor_name'] = 'Ray Zhang'
df.loc[df['actor_name'] == '秦昊', 'actor_name'] = 'Qin Hao'
df.loc[df['actor_name'] == '陈明昊', 'actor_name'] = 'Chen Minghao'
df.loc[df['actor_name'] == '范伟', 'actor_name'] = 'Fan Wei'
df.loc[df['actor_name'] == '范丞丞', 'actor_name'] = 'Fan Chengcheng'
df.loc[df['actor_name'] == '范冰冰', 'actor_name'] = 'Fan Bingbing'
df.loc[df['actor_name'] == '于和伟', 'actor_name'] = 'Yu Hewei'
df.loc[df['actor_name'] == '张桐', 'actor_name'] = 'Zhang Tong'
df.loc[df['actor_name'] == '张晚意', 'actor_name'] = 'Zhang Wanyi'
df.loc[df['actor_name'] == '吴倩', 'actor_name'] = 'Wu Qian'
df.loc[df['actor_name'] == '李纯', 'actor_name'] = 'Li Chun'
df.loc[df['actor_name'] == '张含韵', 'actor_name'] = 'Zhang Hanyun'
df.loc[df['actor_name'] == '杨采钰', 'actor_name'] = 'Yang Caiyu'
df.loc[df['actor_name'] == '杨烁', 'actor_name'] = 'Yang Shuo'
df.loc[df['actor_name'] == '董子健', 'actor_name'] = 'Dong Zijian'
df.loc[df['actor_name'] == '张鲁一', 'actor_name'] = 'Zhang Luyi'
df.loc[df['actor_name'] == '王子文', 'actor_name'] = 'Wang Ziwen'
df.loc[df['actor_name'] == '热依扎·阿里木江', 'actor_name'] = 'Rayzha Alimjan'
df.loc[df['actor_name'] == '张天爱', 'actor_name'] = 'Zhang Tianai'
df.loc[df['actor_name'] == '闫妮', 'actor_name'] = 'Yan Ni'
df.loc[df['actor_name'] == '张嘉益', 'actor_name'] = 'Zhang Jiayi'
df.loc[df['actor_name'] == '罗云熙', 'actor_name'] = 'Luo Yunxi'
df.loc[df['actor_name'] == '陈都灵', 'actor_name'] = 'Chen Duling'
df.loc[df['actor_name'] == '翟子路', 'actor_name'] = 'Zhai Zilu'
df.loc[df['actor_name'] == '宋威龙', 'actor_name'] = 'Song Weilong'
df.loc[df['actor_name'] == '高伟光', 'actor_name'] = 'Gao Weiguang'
df.loc[df['actor_name'] == '陈楚河', 'actor_name'] = 'Chen Chuhe'
df.loc[df['actor_name'] == '景甜', 'actor_name'] = 'Jing Tian'
df.loc[df['actor_name'] == '李沐宸', 'actor_name'] = 'Daisy Li'
df.loc[df['actor_name'] == '周一围', 'actor_name'] = 'Zhou Yiwei'
df.loc[df['actor_name'] == '雷佳音', 'actor_name'] = 'Lei Jiayin'
df.loc[df['actor_name'] == '陈瑾', 'actor_name'] = 'Chen Jin'
df.loc[df['actor_name'] == '廖凡', 'actor_name'] = 'Liao Fan'
df.loc[df['actor_name'] == '陈坤', 'actor_name'] = 'Chen Kun'
df.loc[df['actor_name'] == '谭卓', 'actor_name'] = 'Tan Zhuo'
df.loc[df['actor_name'] == '宁理', 'actor_name'] = 'Ning Li'
df.loc[df['actor_name'] == '李晨', 'actor_name'] = 'Li Chen'
df.loc[df['actor_name'] == '涓子', 'actor_name'] = 'Juanzi'
df.loc[df['actor_name'] == '杨蓉', 'actor_name'] = 'Yang Rong'
df.loc[df['actor_name'] == '李光洁', 'actor_name'] = 'Li Guangjie'
df.loc[df['actor_name'] == '李小璐', 'actor_name'] = 'Li Xiaolu'
df.loc[df['actor_name'] == '李易峰', 'actor_name'] = 'Li Yifeng'
df.loc[df['actor_name'] == '郑晓宁', 'actor_name'] = 'Zheng Xiaoning'
df.loc[df['actor_name'] == '杜晓帆', 'actor_name'] = 'Du Xiaofan'
df.loc[df['actor_name'] == '龚俊', 'actor_name'] = 'Gong Jun'
df.loc[df['actor_name'] == '李宏毅', 'actor_name'] = 'Li Hongyi'
df.loc[df['actor_name'] == '周也', 'actor_name'] = 'Zhou Ye'
df.loc[df['actor_name'] == '马闻远', 'actor_name'] = 'Ma Wenyuan'
df.loc[df['actor_name'] == '张译', 'actor_name'] = 'Zhang Yi'
df.loc[df['actor_name'] == '张颂文', 'actor_name'] = 'Zhang Songwen'
df.loc[df['actor_name'] == '张若昀', 'actor_name'] = 'Zhang Ruoyun'
df.loc[df['actor_name'] == '张峻宁', 'actor_name'] = 'Zhang Juning'
df.loc[df['actor_name'] == '张嘉译', 'actor_name'] = 'Zhang Jiayi'
df.loc[df['actor_name'] == '荣梓杉', 'actor_name'] = 'Rong Zishan'
df.loc[df['actor_name'] == '王景春', 'actor_name'] = 'Wang Jingchun'
df.loc[df['actor_name'] == '王雷', 'actor_name'] = 'Wang Lei'
df.loc[df['actor_name'] == '陈赫', 'actor_name'] = 'Chen He'
df.loc[df['actor_name'] == '宋茜', 'actor_name'] = 'Song Qian'
df.loc[df['actor_name'] == '邢昭林', 'actor_name'] = 'Xing Zhaolin'
df.loc[df['actor_name'] == '宋祖儿', 'actor_name'] = 'Song Zuer'
df.loc[df['actor_name'] == '毛晓彤', 'actor_name'] = 'Mao Xiaotong'
df.loc[df['actor_name'] == '张慧雯', 'actor_name'] = 'Zhang Huiwen'
df.loc[df['actor_name'] == '陈飞宇', 'actor_name'] = 'Chen Feiyu'
df.loc[df['actor_name'] == '张婧仪', 'actor_name'] = 'Zhang Jingyi'
df.loc[df['actor_name'] == '赵志伟', 'actor_name'] = 'Zhao Zhiwei'
df.loc[df['actor_name'] == '丁禹兮', 'actor_name'] = 'Ding Yuxi'
df.loc[df['actor_name'] == '盛英豪', 'actor_name'] = 'Sheng Ying Hao'
df.loc[df['actor_name'] == '宋轶', 'actor_name'] = 'Song Yi'
df.loc[df['actor_name'] == '刘学义', 'actor_name'] = 'Liu Xueyi'
df.loc[df['actor_name'] == '李光洁', 'actor_name'] = 'Karlina Zhang'
df.loc[df['actor_name'] == '向涵之', 'actor_name'] = 'Julia Xiang'
df.loc[df['actor_name'] == '王安宇', 'actor_name'] = 'Wang Anyu'
df.loc[df['actor_name'] == '陈泽', 'actor_name'] = 'Chen Ze'
df.loc[df['actor_name'] == '屈楚萧', 'actor_name'] = 'Qu Chuxiao'
df.loc[df['actor_name'] == '张丰毅', 'actor_name'] = 'Zhang Fengyi'
df.loc[df['actor_name'] == '罗晋', 'actor_name'] = 'Luo Jin'
df.loc[df['actor_name'] == '冯文娟', 'actor_name'] = 'Li Xian'
df.loc[df['actor_name'] == '张鲁一', 'actor_name'] = 'Joyce Feng'
df.loc[df['actor_name'] == '韩栋', 'actor_name'] = 'Han Dong'
df.loc[df['actor_name'] == '肖央', 'actor_name'] = 'Xiao Yang'
df.loc[df['actor_name'] == '王子奇', 'actor_name'] = 'Wang Ziqi'
df.loc[df['actor_name'] == '苏晓彤', 'actor_name'] = 'Su Xiaotong'
df.loc[df['actor_name'] == '赵尧珂', 'actor_name'] = 'Zhao Yaokai'
df.loc[df['actor_name'] == '陈钰琪', 'actor_name'] = 'Chen Yukee'
df.loc[df['actor_name'] == '陈晓', 'actor_name'] = 'Chen Xiao'
df.loc[df['actor_name'] == '王耀庆', 'actor_name'] = 'Wang Yaoqing'
df.loc[df['actor_name'] == '潘粤明', 'actor_name'] = 'Pan Yueming'

# %%
# # How many series that each actor's play
# actor_series = df.groupby('actor_name')['name'].nunique().sort_values(ascending=False)
# # if actor_series < 5, group 1, < 10, group 2, < 15, group 3
# df['group'] = 0
# for i in range(len(actor_series)):
#     if actor_series[i] < 5:
#         df.loc[df['actor_name'] == actor_series.index[i], 'group'] = 1
#     elif actor_series[i] < 10:
#         df.loc[df['actor_name'] == actor_series.index[i], 'group'] = 2
#     elif actor_series[i] < 15:
#         df.loc[df['actor_name'] == actor_series.index[i], 'group'] = 3
#     else:
#         df.loc[df['actor_name'] == actor_series.index[i], 'group'] = 4

# %%
df
# Out:
#                                                 uniq_id    id_new  \
# 0     https://www.douban.com/doubanapp/dispatch?uri=...  27172911
# 1     https://www.douban.com/doubanapp/dispatch?uri=...  27172911
# 2     https://www.douban.com/doubanapp/dispatch?uri=...  27172911
# 3     https://www.douban.com/doubanapp/dispatch?uri=...  27172911
# 4     https://www.douban.com/doubanapp/dispatch?uri=...  27172911
# ...                                                 ...       ...
# 8656  https://www.douban.com/doubanapp/dispatch?uri=...  35539600
# 8657  https://www.douban.com/doubanapp/dispatch?uri=...  35539600
# 8658  https://www.douban.com/doubanapp/dispatch?uri=...  33454980
# 8659  https://www.douban.com/doubanapp/dispatch?uri=...  33454980
# 8660  https://www.douban.com/doubanapp/dispatch?uri=...  33454980
#
#                   name  season    Premiere  Episode  episode_duration_new  \
# 0                 幕后之王     NaN  2019-01-05     46.0                  45.0
# ...

# %%
# save to csv
df.to_csv('translated.csv', index=False)
